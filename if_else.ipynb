# %%
print("hello noorulla")
# Out:
# hello noorulla

# %%
if 5 > 2 :
  print("five is greater than two")
# Out:
# five is greater than two

# %%
#hello this is a comment
print ("this is a comment")
# Out:
# this is a comment

# %%
a = 54
b = "harry"
c = 50.8
print(type(a))
print (type(c))
print(type(b))
print (a+c)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 104.8

# %%
fruits = ["mango","apple","orange"]
x,y,z = fruits
print (x,y,z )
# Out:
# mango apple orange
# mango apple orange

# %%
y = 5j
print(type(y))
# Out:
# <class 'complex'>

# %%
a = 15
b = 30
if a<b :
  print ("a is greater than b")
# Out:
# a is greater than b

# %%
a = 22
b = 22
if a > b :
  print ("a is greater than b ")
else :
 print ("equal")
# Out:
# equal

# %%
"""1.A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
Ask user for their salary and year of service and print the net bonus amount"""
salary = int(input("enter your salary :"))
year = int(input("enter years :"))
if year > 5 :
  print(salary+(0.05*salary))
else:
  print ("not eligible")
# Out:
# enter your salary :25000
# enter years :6
# 26250.0

# %%
"""Take values of length and breadth of a rectangle from user and check if it is square or not."""
lenght = int(input("enter the lenght"))
breadth = int(input("enter the breadth"))
if lenght == breadth :
  print("it is a square ")
else :
  print("it is a rectangle")
# Out:
# enter the lenght8
# enter the breadth8
# it is a square

# %%
"""A school has following rules for grading system:
a. Below 25 - F
b. 25 to 45 - E
c. 45 to 50 - D
d. 50 to 60 - C
e. 60 to 80 - B
f. Above 80 - A
Ask user to enter marks and print the corresponding grade."""
m =int(input("enter marks"))
if m<25 :
  print("f")
elif m >25 and m <= 45 :
  print("e")
elif m >45 and m <= 50 :
  print("d")
elif m >50 and m <= 60 :
  print("c")
elif m > 60 and m <= 80 :
  print("b")
else :
  print("a")
# Out:
# enter marks50
# d

# %%
"""Take two int values from user and print greatest among them."""
a = int(input("enter 1st number "))
b = int(input("enter 2nd number "))
if a>b :
  print("a is greater")
else :
  print("b is greater")
# Out:
# enter 1st number 8
# enter 2nd number 4
# a is greater

# %%
""" Write a program that takes a number as input and checks if it is positive, negative, or zero.
"""
num = int(input("enter a number"))
if num > 0 :
  print("given number is positive")
elif num < 0 :
  print("given number is negative")
else :
  print("given number is zero")
# Out:
# enter a number0
# given number is zero

# %%
""" Create a program that asks the user to enter their age and determines if they are eligible to vote (considering the legal voting age is 18).
"""
a = int(input("enter your age"))
if a > 18 :
  print("you are eligible")
else :
  print("you are not eligible")
# Out:
# enter your age99
# you are eligible

# %%
""" Write a program that takes three numbers as input and finds the largest among them"""
a = int(input("enter 1st num"))
b = int(input("enter 2nd num"))
c = int(input("enter 3rd num"))
if a > b and a > c :
  print(str(a)+" is greater")
elif b > c and b >a :
  print(str(b)+" is greater ")
else :
  print(str(c)+" is greater ")
# Out:
# enter 1st num4
# enter 2nd num6
# enter 3rd num8
# 8 is greater

# %%
""". Develop a program that prompts the user to enter a year and checks if it is a leap year or not """
y = int(input("enter a year"))
if (y = 4 and y != 400) or (y=100) :
  print("it is a leap year")
else :
  print("it is not a leap year")

# %%
""". Develop a program that prompts the user to enter a year and checks if it is a leap year or not """
y = int(input("enter a year"))
if y%4 ==0 and y %  400==0 or y%100 !=0 :
  print("it is a leap year")
else :
  print("it is not a leap year")
# Out:
# enter a year2016
# it is a leap year

# %%
""" Create a program that asks the user to enter a temperature in Celsius and converts it to Fahrenheit if the input is greater than zero; otherwise, it converts it to Kelvin."""
t=int(input("enter the temperature in celsius "))
faren = (t*1.8)+ 32
kelvin = t + 273
if t > 0 :
  print(faren , "degrees in faren")
else :
  print(kelvin , "degrees in kelvin")
# Out:
# enter the temperature in celsius -40
# 233 degrees in kelvin

# %%
""" Write a program that takes a string as input and checks if it is a palindrome (reads the same forwards and backward)."""
a = str(input())
b = a [ ::-1]
if a == b :
  print("it is a palindrome")
else :
  print("it is not a palindrome")
# Out:
# 222
# it is a palindrome
